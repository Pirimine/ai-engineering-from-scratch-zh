# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    "model": ["Linear", "Random Forest", "Neural Net"],
    "accuracy": [0.72, 0.89, 0.94],
    "training_time": [0.1, 2.3, 45.6]
})

df
# Out:
#            model  accuracy  training_time
# 0         Linear      0.72            0.1
# 1  Random Forest      0.89            2.3
# 2     Neural Net      0.94           45.6

# %%
plt.bar(df["model"], df["accuracy"])
plt.title("Model Accuracy")
plt.ylim(0, 1)
plt.show()

# %%
# %timeit [i for i in range(100000)]
# Out:
# 2.5 ms ± 348 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit np.arange(100000)
# Out:
# 32.7 μs ± 1.66 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
